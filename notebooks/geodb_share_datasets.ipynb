# %% [markdown]
# ## Publishing Data

# %%
from xcube_geodb.core.geodb import GeoDBClient

# %%
geodb = GeoDBClient()
geodb.whoami
# Out:
# 'geodb_admin'

# %% [markdown]
# ### Publish Dataset to the world

# %%
geodb.grant_access_to_collection("land_use", 'public')
# Out:
# Access granted on land_use to public

# %%
geodb = GeoDBClient(anonymous=True)
geodb.whoami
# Out:
# 'publicaccess'

# %%
gdf = geodb.get_collection_by_bbox(collection="land_use", bbox=(452750.0, 464000.0, 88909.549, 102486.299),
                           comparison_mode="contains", bbox_crs=3794, limit=200, offset=10, namespace='geodb_admin')
gdf
# Out:
#       id                        created_at modified_at  \
# 0     12  2020-01-30T16:57:28.103408+00:00        None
# 1     13  2020-01-30T16:57:28.103408+00:00        None
# 2     14  2020-01-30T16:57:28.103408+00:00        None
# 3     15  2020-01-30T16:57:28.103408+00:00        None
# 4     16  2020-01-30T16:57:28.103408+00:00        None
# ..   ...                               ...         ...
# 195  215  2020-01-30T16:57:28.103408+00:00        None
# 196  216  2020-01-30T16:57:28.103408+00:00        None
# 197  217  2020-01-30T16:57:28.103408+00:00        None
# 198  218  2020-01-30T16:57:28.103408+00:00        None
# 199  219  2020-01-30T16:57:28.103408+00:00        None
#
#                                               geometry  raba_pid  raba_id  \
# 0    POLYGON ((453673.609 91328.224, 453678.929 913...   5983074     1600
# 1    POLYGON ((460312.295 96127.114, 460300.319 961...   5983199     1600
# 2    POLYGON ((460459.445 96117.356, 460470.516 961...   5983217     1100
# 3    POLYGON ((457798.753 99628.982, 457783.076 996...   6299143     1600
# 4    POLYGON ((461439.703 92137.401, 461436.166 921...   4643632     1600
# ..                                                 ...       ...      ...
# 195  POLYGON ((458934.146 95656.658, 458932.345 956...   5966575     1222
# 196  POLYGON ((458934.146 95656.658, 458935.525 956...   5966577     1100
# 197  POLYGON ((455301.879 91279.877, 455302.373 912...   2594677     1100
# 198  POLYGON ((455207.927 91222.221, 455193.596 912...   2594678     1100
# 199  POLYGON ((456955.636 98474.696, 456952.435 984...   2960296     1500
#
#            d_od
# 0    2019-03-26
# 1    2019-03-11
# 2    2019-03-11
# 3    2019-03-04
# 4    2019-02-21
# ..          ...
# 195  2019-01-05
# 196  2019-01-05
# 197  2019-03-14
# 198  2019-03-14
# 199  2019-02-26
#
# [200 rows x 7 columns]

# %% [markdown]
# ## Revoke access

# %%
geodb = GeoDBClient()
geodb.whoami
# Out:
# 'geodb_admin'

# %%
geodb.list_grants()
# Out:
# [{'table_name': 'geodb_admin_land_use', 'grantee': 'PUBLIC'}]

# %%
geodb.revoke_access_from_collection("land_use")
# Out:
# Access revoked from land_use of public

# %%
geodb = GeoDBClient(anonymous=True)
geodb.whoami
# Out:
# 'publicaccess'

# %%
gdf = geodb.get_collection_by_bbox(collection="land_use", bbox=(452750.0, 88909.549, 464000.0, 102486.299),
                comparison_mode="contains", bbox_crs=3794, limit=2, offset=10, namespace='geodb_admin')
gdf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-bf267c99e20a> in <module>
#       1 gdf = geodb.get_collection_by_bbox(collection="land_use", bbox=(452750.0, 88909.549, 464000.0, 102486.299),
# ----> 2                 comparison_mode="contains", bbox_crs=3794, limit=2, offset=10, namespace='geodb_admin')
#       3 gdf
#
# c:\users\helge\ideaprojects\dcfs-geodb\xcube_geodb\core\geodb.py in get_collection_by_bbox(self, collection, bbox, comparison_mode, bbox_crs, limit, offset, namespace)
#     709         dn = f"{tab_prefix}_{collection}"
#     710
# --> 711         self._raise_for_collection_exists(collection=dn)
#     712         self._raise_for_stored_procedure_exists('geodb_get_by_bbox')
#     713
#
# c:\users\helge\ideaprojects\dcfs-geodb\xcube_geodb\core\geodb.py in _raise_for_collection_exists(self, collection)
#    1071             return True
#    1072         else:
# -> 1073             raise ValueError(f"Collection {collection} does not exist")
#    1074
#    1075     def _raise_for_stored_procedure_exists(self, stored_procedure: str) -> bool:
#
# ValueError: Collection geodb_admin_land_use does not exist

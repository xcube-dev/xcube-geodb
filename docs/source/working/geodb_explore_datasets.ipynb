# %% [markdown]
# ## Exploring Data

# %% [markdown]
# ### Connect to GeoDB

# %%
from xcube_geodb.core.geodb import GeoDBClient

# %%
geodb = GeoDBClient()
geodb.whoami
# Out:
# 'geodb_admin'

# %% [markdown]
# ### List Datasets
#
# __Step 1__: List my datasets.

# %%
geodb.get_collections()
# Out:
#   table_name
# 0   land_use

# %% [markdown]
# ### Get the whole Collection

# %%
gdf = geodb.get_collection('land_use')
gdf
# Out:
#         id                        created_at                      modified_at  \
# 0        1  2020-01-31T11:08:35.241344+00:00                             None
# 1       10  2020-01-31T11:08:35.241344+00:00  2020-01-31T11:09:11.84153+00:00
# 2        4  2020-01-31T11:08:35.241344+00:00                             None
# 3        5  2020-01-31T11:08:35.241344+00:00                             None
# 4        6  2020-01-31T11:08:35.241344+00:00                             None
# ...    ...                               ...                              ...
# 9438  9766  2020-01-31T11:08:35.241344+00:00  2020-01-31T11:09:11.84153+00:00
# 9439  9767  2020-01-31T11:08:35.241344+00:00  2020-01-31T11:09:11.84153+00:00
# 9440  9798  2020-01-31T11:08:35.241344+00:00  2020-01-31T11:09:11.84153+00:00
# 9441  9799  2020-01-31T11:08:35.241344+00:00  2020-01-31T11:09:11.84153+00:00
# 9442  9821  2020-01-31T11:08:35.241344+00:00  2020-01-31T11:09:11.84153+00:00
#
#                                                geometry  raba_pid  raba_id  \
# 0     POLYGON ((453952.629 91124.177, 453952.696 911...   4770326     1410
# 1     POLYGON ((456547.427 91543.640, 456544.255 915...   2318555     1300
# 2     POLYGON ((455929.405 97963.785, 455933.284 979...   2305596     1100
# 3     POLYGON ((461561.512 96119.256, 461632.114 960...   2310160     1100
# 4     POLYGON ((458139.092 95583.227, 458136.249 955...   3602865     1500
# ...                                                 ...       ...      ...
# 9438  POLYGON ((458247.583 99746.065, 458245.202 997...   6268059     1300
# 9439  POLYGON ((461932.283 90520.703, 461931.619 905...   6263561     1300
# 9440  POLYGON ((457231.170 90902.256, 457234.861 909...   6264862     1300
# 9441  POLYGON ((461378.845 91124.318, 461490.224 911...   6264865     1300
# 9442  POLYGON ((457450.306 97213.244, 457490.521 972...   6263915     1300
#
#             d_od
# 0     2019-03-26
# 1     2000-01-01
# 2     2019-02-25
# 3     2019-03-11
# 4     2019-01-05
# ...          ...
# 9438  2000-01-01
# 9439  2000-01-01
# 9440  2000-01-01
# 9441  2000-01-01
# 9442  2000-01-01
#
# [9443 rows x 7 columns]

# %%
gdf.plot(column="raba_pid", figsize=(15,15))

# %% [markdown]
# ### Use Postgrest Syntax

# %%
gdfsub = geodb.get_collection('land_use', query='limit=150&raba_id=eq.1410')
gdfsub
# Out:
#        id                        created_at modified_at  \
# 0       1  2020-01-31T11:08:35.241344+00:00        None
# 1      62  2020-01-31T11:08:35.241344+00:00        None
# 2      22  2020-01-31T11:08:35.241344+00:00        None
# 3      28  2020-01-31T11:08:35.241344+00:00        None
# 4      32  2020-01-31T11:08:35.241344+00:00        None
# ..    ...                               ...         ...
# 145  1360  2020-01-31T11:08:35.241344+00:00        None
# 146  1361  2020-01-31T11:08:35.241344+00:00        None
# 147  1364  2020-01-31T11:08:35.241344+00:00        None
# 148  1367  2020-01-31T11:08:35.241344+00:00        None
# 149  1408  2020-01-31T11:08:35.241344+00:00        None
#
#                                               geometry  raba_pid  raba_id  \
# 0    POLYGON ((453952.629 91124.177, 453952.696 911...   4770326     1410
# 1    POLYGON ((457261.001 96349.254, 457256.831 963...   3596498     1410
# 2    POLYGON ((455384.809 97907.054, 455380.659 979...   3616776     1410
# 3    POLYGON ((462585.734 93088.987, 462567.020 930...   3826126     1410
# 4    POLYGON ((457748.827 96167.354, 457748.394 961...   2309744     1410
# ..                                                 ...       ...      ...
# 145  POLYGON ((461378.889 94225.210, 461454.167 942...    213271     1410
# 146  POLYGON ((458943.795 97613.650, 458919.415 976...   3594724     1410
# 147  POLYGON ((453661.078 91486.491, 453601.873 914...   3545928     1410
# 148  POLYGON ((457466.798 98830.247, 457457.276 988...    209978     1410
# 149  POLYGON ((462188.005 94162.374, 462190.018 941...   5982484     1410
#
#            d_od
# 0    2019-03-26
# 1    2019-01-05
# 2    2019-02-25
# 3    2019-01-23
# 4    2019-01-05
# ..          ...
# 145  2019-03-11
# 146  2019-03-04
# 147  2019-01-05
# 148  2019-03-04
# 149  2019-03-20
#
# [150 rows x 7 columns]

# %%
gdfsub.plot(column="raba_id", figsize=(15,15))

# %% [markdown]
# ### Get a Collection using a Bounding Box

# %%
gdf = geodb.get_collection_by_bbox(collection="land_use", bbox=(452750.0, 464000.0, 88909.549, 102486.299),
                           comparison_mode="contains", bbox_crs=3794, limit=200, offset=10)
gdf
# Out:
#       id                        created_at modified_at  \
# 0     12  2020-01-31T11:08:35.241344+00:00        None
# 1     13  2020-01-31T11:08:35.241344+00:00        None
# 2     14  2020-01-31T11:08:35.241344+00:00        None
# 3     15  2020-01-31T11:08:35.241344+00:00        None
# 4     16  2020-01-31T11:08:35.241344+00:00        None
# ..   ...                               ...         ...
# 195  215  2020-01-31T11:08:35.241344+00:00        None
# 196  216  2020-01-31T11:08:35.241344+00:00        None
# 197  217  2020-01-31T11:08:35.241344+00:00        None
# 198  218  2020-01-31T11:08:35.241344+00:00        None
# 199  219  2020-01-31T11:08:35.241344+00:00        None
#
#                                               geometry  raba_pid  raba_id  \
# 0    POLYGON ((453673.609 91328.224, 453678.929 913...   5983074     1600
# 1    POLYGON ((460312.295 96127.114, 460300.319 961...   5983199     1600
# 2    POLYGON ((460459.445 96117.356, 460470.516 961...   5983217     1100
# 3    POLYGON ((457798.753 99628.982, 457783.076 996...   6299143     1600
# 4    POLYGON ((461439.703 92137.401, 461436.166 921...   4643632     1600
# ..                                                 ...       ...      ...
# 195  POLYGON ((458934.146 95656.658, 458932.345 956...   5966575     1222
# 196  POLYGON ((458934.146 95656.658, 458935.525 956...   5966577     1100
# 197  POLYGON ((455301.879 91279.877, 455302.373 912...   2594677     1100
# 198  POLYGON ((455207.927 91222.221, 455193.596 912...   2594678     1100
# 199  POLYGON ((456955.636 98474.696, 456952.435 984...   2960296     1500
#
#            d_od
# 0    2019-03-26
# 1    2019-03-11
# 2    2019-03-11
# 3    2019-03-04
# 4    2019-02-21
# ..          ...
# 195  2019-01-05
# 196  2019-01-05
# 197  2019-03-14
# 198  2019-03-14
# 199  2019-02-26
#
# [200 rows x 7 columns]

# %%
gdf.plot(column="raba_pid", figsize=(15,15))

# %% [markdown]
# ### Get Collection using PostGreSQL Syntax

# %%
gdf = geodb.get_collection_pg(collection='land_use', where='raba_id=1410')
gdf.head()
# Out:
#    id                        created_at modified_at  \
# 0   1  2020-01-31T11:08:35.241344+00:00        None
# 1  62  2020-01-31T11:08:35.241344+00:00        None
# 2  22  2020-01-31T11:08:35.241344+00:00        None
# 3  28  2020-01-31T11:08:35.241344+00:00        None
# 4  32  2020-01-31T11:08:35.241344+00:00        None
#
#                                             geometry  raba_pid  raba_id  \
# 0  POLYGON ((453952.629 91124.177, 453952.696 911...   4770326     1410
# 1  POLYGON ((457261.001 96349.254, 457256.831 963...   3596498     1410
# 2  POLYGON ((455384.809 97907.054, 455380.659 979...   3616776     1410
# 3  POLYGON ((462585.734 93088.987, 462567.020 930...   3826126     1410
# 4  POLYGON ((457748.827 96167.354, 457748.394 961...   2309744     1410
#
#          d_od
# 0  2019-03-26
# 1  2019-01-05
# 2  2019-02-25
# 3  2019-01-23
# 4  2019-01-05

# %%
gdf.plot(column="raba_pid", figsize=(15,15))

# %% [markdown]
# ### Query the collection using the PostGreSQL Syntax for Advanced Aggregation

# %%
df = geodb.get_collection_pg('land_use', where='raba_id=1410', group='d_od', select='COUNT(d_od) as ct, d_od')
df.head()
# Out:
#    ct        d_od
# 0  12  2019-03-21
# 1  47  2019-02-25
# 2  17  2019-03-13
# 3  26  2019-02-20
# 4   2  2019-04-29
